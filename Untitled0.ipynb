# %% [markdown]
# <a href="https://colab.research.google.com/github/123111222/GEE_Cloud-computing/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee

ee.Authenticate()

ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=lp1-2wV0mBj06jLRXB1twKxOSCKq4SGm0DcztlsJPsI&tc=xszSznYFEYwUONaLv4hy9WwwRfr1iRNnPOBi8zuGpYM&cc=5KTDVKvsExbtX7ON3yeIuQBSXlSFpk20H5IQ92jhhV0
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BV1HdRn7R5Pb4GyDwRxdixfoux_vH5N0AxF6GM4ew3n_Zjo9oRmwJE
#
# Successfully saved authorization token.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install geemap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 51.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.4 MB/s eta 0:00:00
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11125 sha256=e4551cec16fc63e753181967517887fe4532ede77b4bd40a87aa446d0bae85d9
# ...

# %%
import geemap
import os
import geemap.colormaps as cm

# %%
Map = geemap.Map(center=(0, 0), zoom=2)

modis_dataset = ee.ImageCollection('MODIS/061/MOD13A2') \
    .filterDate('2015-01-01', '2022-12-31') \
    .select('NDVI')

image = modis_dataset.toBands()

palette = cm.palettes.ndvi
ndvi_vis = {
  'min': 0.0,
  'max': 8000.0,
  'palette': palette
}

Map.addLayer(image, {}, 'MODIS NDVI Time-series')
Map.addLayer(image.select(20), ndvi_vis, 'MODIS NDVI VIS')

Map.set_plot_options(add_marker_cluster=True, marker=None)

Map.add_colorbar(ndvi_vis, label="NDVI", layer_name='MODIS NDVI VIS')
Map
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Toggl…

# %%
out_dir = '/Alice'
out_csv = os.path.join(out_dir, 'global vegetation cover.csv')
Map.extract_values_to_points(out_csv)
# Out:
# The csv file has been saved to: /Alice/global vegetation cover.csv

# %%
from google.colab import files
files.download('/Alice/global vegetation cover.csv')

# %%
import numpy as np

def ws(y, r=2, d=3):
    y = np.array(y, dtype=np.float64)
    if y[(y<-2000)|(y>10000)].size:
        raise ValueError("The range of valid values should follow the band!")
    m = y.size
    E = np.eye(m)
    D = np.diff(E, n=d, axis=0)
    t = E+r*np.dot(D.T, D)
    z = np.dot(np.linalg.inv(t), y.T)
    return z

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/Alice/global vegetation cover.csv')

for i in range(df.shape[0]):
    id = df.loc[i, 'id']
    point_NDVI = df.iloc[i, 3:]
    try:
        if (point_NDVI < 0).any():
            plt.figure(figsize=(16, 5), constrained_layout=True)
            plt.title("Point {} (Data with Anomalies)".format(id))
            plt.plot(np.arange(len(point_NDVI)), point_NDVI, 'k-', label="NDVI")
            plt.scatter(np.where(point_NDVI < 0)[0], point_NDVI[point_NDVI < 0], color='r', alpha=1, marker='o', label="NaN")
            plt.xticks(np.arange(len(point_NDVI))[::23], ['2015-01-01','2016-01-01','2017-01-01','2018-01-01','2019-01-01','2020-01-01','2021-01-01','2022-01-01'])
            plt.legend(loc='upper left')
        else:
            smooth_point_NDVI = ws(point_NDVI)
            plt.figure(figsize=(16, 5), constrained_layout=True)
            plt.title("Point {} (Smoothed)".format(id))
            plt.plot(np.arange(len(point_NDVI)), point_NDVI, 'k-', label="Raw NDVI")
            plt.plot(np.arange(len(smooth_point_NDVI)), smooth_point_NDVI, 'r--', label="Whittaker (Smoothed)")
            plt.xticks(np.arange(len(point_NDVI))[::23], ['2015-01-01','2016-01-01','2017-01-01','2018-01-01','2019-01-01','2020-01-01','2021-01-01','2022-01-01'])
            plt.legend()
    except Exception as e:
        print(e)
        continue
