# %% [markdown]
# <a href="https://colab.research.google.com/github/123111222/GEE_Cloud-computing/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ee

ee.Authenticate()

ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=YVjotsnrgqcMHMLEeikIWi-dZQKFd0sawSasNXWaS30&tc=pnbV8hbShOlaYKAqBscj0h67Xtu6B3GNd2Uhn4p6oa8&cc=Um6fgb67B5C6fuXF20DgoilDSjUVb3uqg9xmthUq9Fg
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BW1rzepvgvdPqLTImZiYFWtJYPZXtsJeNJOxrDfaI80vg7Hdk02iG8
#
# Successfully saved authorization token.

# %%
from IPython.display import Image
dem = ee.Image('USGS/SRTMGL1_003')
processed_dem = dem.updateMask(dem.gt(0))
visualization_params = {
    'min': 0,
    'max': 4000,
    'dimensions': 512,
    'palette': ['006633',
                'E5FFCC',
                '662A00',
                'D8D8D8',
                'F5F5F5']
}


thumbnail_url = processed_dem.getThumbURL(visualization_params)


Image(url=thumbnail_url)
# Out:
# <img src="https://earthengine.googleapis.com/v1/projects/earthengine-legacy/thumbnails/df5c3239c03299d4153fb8cb9563623c-0f14f08101876591b611b9eee991ef60:getPixels"/>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import ee

# %%
# !pip install geemap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 29.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.0 MB/s eta 0:00:00
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11125 sha256=a097c84a2b40c8db136aaaf3cca35511b25fc7a336a6a8f493679243d73bbb4b
# ...

# %%
import geemap

# %%
Map = geemap.Map(center=(0, 0), zoom=3)
Map
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Toggl…

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import ee
import os
import geemap
import geemap.colormaps as cm

ee.Authenticate()

ee.Initialize()
# Out:
# To authorize access needed by Earth Engine, open the following URL in a web browser and follow the instructions. If the web browser does not start automatically, please manually browse the URL below.
#
#     https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=O3SRj3XfIyDW9cZWrGOSWEZJ6D5t1dt-qo2ggaM2iZQ&tc=JztdzCm-WUQzVucVuRjU_iNqZbdBP0tHYhJ2z6GQy_M&cc=5VGFFIrmcXaFM6m0zMr8py2qV8B-WEHnM0e5mfvBQmc
#
# The authorization workflow will generate a code, which you should paste in the box below.
# Enter verification code: 4/1Adeu5BUdiHVuKjt7Cg_WruBOGQiIGASNpKPkPWZWzcijClBshW_ZzxtIjX8
#
# Successfully saved authorization token.

# %%
import ee
import geemap

ee.Initialize()

Map = geemap.Map(center=(0, 0), zoom=2)

modis_dataset = ee.ImageCollection('MODIS/006/MOD13A2') \
    .filterDate('2015-01-01', '2020-12-31') \
    .select('NDVI')

image = modis_dataset.toBands()

palette = cm.palettes.ndvi
ndvi_vis = {
  'min': 0.0,
  'max': 8000.0,
  'palette': palette
}

Map.addLayer(image, {}, 'MODIS NDVI Time-series')
Map.addLayer(image.select(20), ndvi_vis, 'MODIS NDVI VIS')

Map.set_plot_options(add_marker_cluster=True, marker=None)

Map.add_colorbar(ndvi_vis, label="NDVI", layer_name='MODIS NDVI VIS')
Map
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Toggl…

# %%
out_dir = '/Alice'
out_csv = os.path.join(out_dir, 'global vegetation cover.csv')
Map.extract_values_to_points(out_csv)
# Out:
# The csv file has been saved to: /Alice/global vegetation cover.csv

# %%
import numpy as np

def ws(y, r=2, d=3):
    y = np.array(y, dtype=np.float64)
    if y[(y>10000)].size:
        raise ValueError("The range of valid values should below 10000!")
    m = y.size
    E = np.eye(m)
    D = np.diff(E, n=d, axis=0)
    t = E+r*np.dot(D.T, D)
    z = np.dot(np.linalg.inv(t), y.T)
    return z

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/Alice/global vegetation cover.csv')

for i in range(df.shape[0]):
    id = df.loc[i, 'id']
    point_NDVI = df.iloc[i, 3:]
    try:
        smooth_point_NDVI = ws(point_NDVI)
    except Exception as e:
        print(e)
        continue
    plt.figure(figsize=(16, 4), constrained_layout=True)
    plt.title("Point {}".format(id))
    plt.plot(np.arange(len(point_NDVI)), point_NDVI, 'k-', label="Raw NDVI")
    plt.plot(np.arange(len(smooth_point_NDVI)), smooth_point_NDVI, 'r--', label="Whittaker")
    plt.xticks(np.arange(len(point_NDVI))[::46], ['2015-01-01','2017-01-01','2019-01-01'])
    plt.legend()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/Alice/global vegetation cover.csv')

for i in range(df.shape[0]):
    id = df.loc[i, 'id']
    point_NDVI = df.iloc[i, 3:]
    try:
        if (point_NDVI < 0).any():
            plt.figure(figsize=(16, 4), constrained_layout=True)
            plt.title("Point {} (Data with Anomalies)".format(id))
            plt.plot(np.arange(len(point_NDVI)), point_NDVI, 'k-', label="NDVI")
            plt.scatter(np.where(point_NDVI < 0)[0], point_NDVI[point_NDVI < 0], color='r', label="NaN")
            plt.xticks(np.arange(len(point_NDVI))[::46], ['2015-01-01','2017-01-01','2019-01-01'])
            plt.legend(loc='upper left')
        else:
            smooth_point_NDVI = ws(point_NDVI)
            plt.figure(figsize=(16, 4), constrained_layout=True)
            plt.title("Point {} (Smoothed)".format(id))
            plt.plot(np.arange(len(point_NDVI)), point_NDVI, 'k-', label="Raw NDVI")
            plt.plot(np.arange(len(smooth_point_NDVI)), smooth_point_NDVI, 'r--', label="Whittaker (Smoothed)")
            plt.xticks(np.arange(len(point_NDVI))[::46], ['2015-01-01','2017-01-01','2019-01-01'])
            plt.legend()
    except Exception as e:
        print(e)
        continue
